# %%
import pandas as pd
import numpy as np

# %%
wr_csv = "resources/FantasyPros_2022_Week_10_WR_Rankings.csv"

# %%
wr_df = pd.read_csv(wr_csv)
wr_df.head(20)
# Out:
#     RK          PLAYER_NAME TEAM      OPP MATCHUP_RATING START_SIT PROJ_FPTS  \
# 0    1          Tyreek Hill  MIA  vs. CLE            7.2        A+      22.3
# 1    2          Cooper Kupp  LAR  vs. ARI            7.8        A+      22.2
# 2    3         Stefon Diggs  BUF  vs. MIN            7.6        A+      20.2
# 3    4     Justin Jefferson  MIN   at BUF            6.6        A+      19.4
# 4    5        Davante Adams   LV  vs. IND            6.4        A+      19.0
# 5    6        Jaylen Waddle  MIA  vs. CLE            7.2        A+      18.1
# 6    7      DeAndre Hopkins  ARI   at LAR            6.6         A      17.9
# 7    8    Amon-Ra St. Brown  DET   at CHI            8.4         A      16.9
# 8    9           A.J. Brown  PHI  vs. WAS            7.0         A      16.5
# 9   10          CeeDee Lamb  DAL    at GB            5.8         A      15.8
# 10  11           Mike Evans   TB  vs. SEA            5.4         A      15.8
# ...

# %%
wr_df.columns
wr_df.dtypes
# Out:
# RK                       int64
# PLAYER_NAME             object
# TEAM                    object
# OPP                     object
# MATCHUP_RATING          object
# START_SIT               object
# PROJ_FPTS               object
# AVG_POINTS              object
# Percentage_of_GAMES     object
# OPPORTUNITY             object
# EFFICIENCY              object
# dtype: object

# %%
no_null_rate_df= wr_df.dropna(how="-")
no_null_rate_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10872\9853591.py in <module>
# ----> 1 no_null_rate_df= wr_df.dropna(how="-")
#       2 no_null_rate_df.head(20)
#
# c:\Users\18176\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4759         else:
#    4760             if how is not None:
# -> 4761                 raise ValueError(f"invalid how option: {how}")
#    4762             else:
#    4763                 raise TypeError("must specify how or thresh")
#
# ValueError: invalid how option: -

# %%
wr_df['MATCHUP_RATING']= wr_df['MATCHUP_RATING'].astype(float)
print(wr_df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10872\478620872.py in <module>
# ----> 1 wr_df['MATCHUP_RATING']= wr_df['MATCHUP_RATING'].astype(float)
#       2 print(wr_df.dtypes)
#
# c:\Users\18176\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\Users\18176\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# ...

# %%
Over_df = wr_df.loc[wr_df['MATCHUP_RATING'] ,
["RK","PLAYER_NAME","TEAM","OPP","MATCHUP_RATING","START_SIT","PROJ_FPTS","AVG_POINTS","Percentage_of_GAMES","OPPORTUNITY","EFFICIENCY"] ]
Over_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10872\2191095211.py in <module>
# ----> 1 wr_df['MATCHUP_RATING'].astype(int)
#       2 Over_df = wr_df.loc[wr_df['MATCHUP_RATING'] ,
#       3 ["RK","PLAYER_NAME","TEAM","OPP","MATCHUP_RATING","START_SIT","PROJ_FPTS","AVG_POINTS","Percentage_of_GAMES","OPPORTUNITY","EFFICIENCY"] ]
#       4 Over_df.head()
#
# c:\Users\18176\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...
